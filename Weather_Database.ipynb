# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from datetime import datetime
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_current = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),                         
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Current Description": city_current,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kapaa
# Processing Record 2 of Set 1 | hithadhoo
# Processing Record 3 of Set 1 | togur
# Processing Record 4 of Set 1 | mitsamiouli
# Processing Record 5 of Set 1 | puerto cabezas
# Processing Record 6 of Set 1 | hatillo
# Processing Record 7 of Set 1 | hilo
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | longyearbyen
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | iralaya
# Processing Record 12 of Set 1 | vestmannaeyjar
# Processing Record 13 of Set 1 | butaritari
# Processing Record 14 of Set 1 | tarudant
# City not found. Skipping...
# Processing Record 15 of Set 1 | yatsushiro
# Processing Record 16 of Set 1 | namibe
# Processing Record 17 of Set 1 | bengkulu
# Processing Record 18 of Set 1 | qaanaaq
# Processing Record 19 of Set 1 | penzance
# Processing Record 20 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 21 of Set 1 | jalu
# Processing Record 22 of Set 1 | salalah
# Processing Record 23 of Set 1 | mataura
# Processing Record 24 of Set 1 | bredasdorp
# Processing Record 25 of Set 1 | astoria
# Processing Record 26 of Set 1 | kodiak
# Processing Record 27 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 28 of Set 1 | semirom
# Processing Record 29 of Set 1 | dzhusaly
# City not found. Skipping...
# Processing Record 30 of Set 1 | faanui
# Processing Record 31 of Set 1 | abu samrah
# Processing Record 32 of Set 1 | punta arenas
# Processing Record 33 of Set 1 | port alfred
# Processing Record 34 of Set 1 | ust-tsilma
# Processing Record 35 of Set 1 | husavik
# Processing Record 36 of Set 1 | nikolskoye
# Processing Record 37 of Set 1 | busselton
# Processing Record 38 of Set 1 | puerto ayora
# Processing Record 39 of Set 1 | saint-philippe
# Processing Record 40 of Set 1 | calca
# Processing Record 41 of Set 1 | komsomolets
# Processing Record 42 of Set 1 | yellowknife
# Processing Record 43 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 1 | moron
# Processing Record 45 of Set 1 | guerrero negro
# Processing Record 46 of Set 1 | tual
# Processing Record 47 of Set 1 | torbay
# Processing Record 48 of Set 1 | pasni
# Processing Record 49 of Set 1 | tasiilaq
# Processing Record 50 of Set 1 | sataua
# City not found. Skipping...
# Processing Record 1 of Set 2 | haverfordwest
# Processing Record 2 of Set 2 | esmeraldas
# Processing Record 3 of Set 2 | isla vista
# Processing Record 4 of Set 2 | kungurtug
# Processing Record 5 of Set 2 | bluff
# Processing Record 6 of Set 2 | severo-kurilsk
# Processing Record 7 of Set 2 | vaini
# Processing Record 8 of Set 2 | jamestown
# Processing Record 9 of Set 2 | albany
# Processing Record 10 of Set 2 | hobart
# Processing Record 11 of Set 2 | mackay
# Processing Record 12 of Set 2 | tiksi
# Processing Record 13 of Set 2 | henties bay
# Processing Record 14 of Set 2 | kadykchan
# City not found. Skipping...
# Processing Record 15 of Set 2 | svetlogorsk
# Processing Record 16 of Set 2 | atuona
# Processing Record 17 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 18 of Set 2 | cabo san lucas
# Processing Record 19 of Set 2 | chimoio
# Processing Record 20 of Set 2 | bouca
# Processing Record 21 of Set 2 | yeniseysk
# Processing Record 22 of Set 2 | takoradi
# Processing Record 23 of Set 2 | juneau
# Processing Record 24 of Set 2 | ust-ishim
# Processing Record 25 of Set 2 | belyy yar
# Processing Record 26 of Set 2 | nizwa
# Processing Record 27 of Set 2 | gravdal
# Processing Record 28 of Set 2 | pundaguitan
# Processing Record 29 of Set 2 | cidreira
# Processing Record 30 of Set 2 | half moon bay
# Processing Record 31 of Set 2 | grootfontein
# Processing Record 32 of Set 2 | bani walid
# Processing Record 33 of Set 2 | new norfolk
# Processing Record 34 of Set 2 | tabou
# Processing Record 35 of Set 2 | anloga
# Processing Record 36 of Set 2 | saskylakh
# Processing Record 37 of Set 2 | laramie
# Processing Record 38 of Set 2 | ler
# Processing Record 39 of Set 2 | komsomolskiy
# Processing Record 40 of Set 2 | avarua
# Processing Record 41 of Set 2 | severnyy
# Processing Record 42 of Set 2 | lebu
# Processing Record 43 of Set 2 | nome
# Processing Record 44 of Set 2 | cape town
# Processing Record 45 of Set 2 | dikson
# Processing Record 46 of Set 2 | broken hill
# Processing Record 47 of Set 2 | kirkuk
# Processing Record 48 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 49 of Set 2 | panjakent
# Processing Record 50 of Set 2 | polyarnyy
# Processing Record 1 of Set 3 | umba
# Processing Record 2 of Set 3 | yulara
# Processing Record 3 of Set 3 | hasaki
# Processing Record 4 of Set 3 | mahebourg
# Processing Record 5 of Set 3 | port elizabeth
# Processing Record 6 of Set 3 | chokurdakh
# Processing Record 7 of Set 3 | shingu
# Processing Record 8 of Set 3 | avera
# Processing Record 9 of Set 3 | chuy
# Processing Record 10 of Set 3 | silver city
# Processing Record 11 of Set 3 | coquimbo
# Processing Record 12 of Set 3 | bandarbeyla
# Processing Record 13 of Set 3 | luganville
# Processing Record 14 of Set 3 | bud
# Processing Record 15 of Set 3 | tiznit
# Processing Record 16 of Set 3 | carnarvon
# Processing Record 17 of Set 3 | turinskaya sloboda
# Processing Record 18 of Set 3 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 19 of Set 3 | chaihe
# Processing Record 20 of Set 3 | joshimath
# Processing Record 21 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 3 | hami
# Processing Record 23 of Set 3 | sept-iles
# Processing Record 24 of Set 3 | saraland
# Processing Record 25 of Set 3 | ponta do sol
# Processing Record 26 of Set 3 | ambodifototra
# City not found. Skipping...
# Processing Record 27 of Set 3 | marystown
# Processing Record 28 of Set 3 | yarmouth
# Processing Record 29 of Set 3 | anadyr
# Processing Record 30 of Set 3 | vegreville
# Processing Record 31 of Set 3 | haines junction
# Processing Record 32 of Set 3 | pisco
# Processing Record 33 of Set 3 | kibala
# Processing Record 34 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 35 of Set 3 | karratha
# Processing Record 36 of Set 3 | ziezmariai
# Processing Record 37 of Set 3 | amapa
# Processing Record 38 of Set 3 | leningradskiy
# Processing Record 39 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 40 of Set 3 | kampot
# Processing Record 41 of Set 3 | sao filipe
# Processing Record 42 of Set 3 | ancud
# Processing Record 43 of Set 3 | mount gambier
# Processing Record 44 of Set 3 | iwanai
# Processing Record 45 of Set 3 | ust-nera
# Processing Record 46 of Set 3 | mar del plata
# Processing Record 47 of Set 3 | taltal
# Processing Record 48 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 49 of Set 3 | sitka
# Processing Record 50 of Set 3 | palmer
# Processing Record 1 of Set 4 | constitucion
# Processing Record 2 of Set 4 | samarai
# Processing Record 3 of Set 4 | hermanus
# Processing Record 4 of Set 4 | provideniya
# Processing Record 5 of Set 4 | yinchuan
# Processing Record 6 of Set 4 | phan rang
# City not found. Skipping...
# Processing Record 7 of Set 4 | naze
# Processing Record 8 of Set 4 | deputatskiy
# Processing Record 9 of Set 4 | lufilufi
# Processing Record 10 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 4 | norman wells
# Processing Record 12 of Set 4 | formoso do araguaia
# City not found. Skipping...
# Processing Record 13 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 14 of Set 4 | esperance
# Processing Record 15 of Set 4 | east london
# Processing Record 16 of Set 4 | souillac
# Processing Record 17 of Set 4 | codrington
# Processing Record 18 of Set 4 | warrington
# Processing Record 19 of Set 4 | menongue
# Processing Record 20 of Set 4 | ullapool
# Processing Record 21 of Set 4 | cherskiy
# Processing Record 22 of Set 4 | nalut
# Processing Record 23 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 24 of Set 4 | praia da vitoria
# Processing Record 25 of Set 4 | walvis bay
# Processing Record 26 of Set 4 | ulladulla
# Processing Record 27 of Set 4 | belmonte
# Processing Record 28 of Set 4 | port macquarie
# Processing Record 29 of Set 4 | serzhen-yurt
# Processing Record 30 of Set 4 | chapais
# Processing Record 31 of Set 4 | haimen
# Processing Record 32 of Set 4 | jarjis
# City not found. Skipping...
# Processing Record 33 of Set 4 | mizdah
# Processing Record 34 of Set 4 | padang
# Processing Record 35 of Set 4 | te anau
# Processing Record 36 of Set 4 | sitarganj
# Processing Record 37 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 4 | unity
# Processing Record 39 of Set 4 | bambous virieux
# Processing Record 40 of Set 4 | grand gaube
# Processing Record 41 of Set 4 | castro
# Processing Record 42 of Set 4 | alcudia
# Processing Record 43 of Set 4 | tawkar
# City not found. Skipping...
# Processing Record 44 of Set 4 | pivijay
# Processing Record 45 of Set 4 | tuktoyaktuk
# Processing Record 46 of Set 4 | healdsburg
# Processing Record 47 of Set 4 | tours
# Processing Record 48 of Set 4 | mattru
# Processing Record 49 of Set 4 | le port
# Processing Record 50 of Set 4 | constantine
# Processing Record 1 of Set 5 | benguela
# Processing Record 2 of Set 5 | rocky mountain house
# Processing Record 3 of Set 5 | hamilton
# Processing Record 4 of Set 5 | marawi
# Processing Record 5 of Set 5 | teya
# Processing Record 6 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 7 of Set 5 | arraial do cabo
# Processing Record 8 of Set 5 | iqaluit
# Processing Record 9 of Set 5 | esik
# Processing Record 10 of Set 5 | saint-joseph
# Processing Record 11 of Set 5 | necochea
# Processing Record 12 of Set 5 | bombay
# Processing Record 13 of Set 5 | pevek
# Processing Record 14 of Set 5 | jaque
# Processing Record 15 of Set 5 | el alto
# Processing Record 16 of Set 5 | shaunavon
# Processing Record 17 of Set 5 | whitehorse
# Processing Record 18 of Set 5 | ban nahin
# Processing Record 19 of Set 5 | williams lake
# Processing Record 20 of Set 5 | alofi
# Processing Record 21 of Set 5 | manzhouli
# Processing Record 22 of Set 5 | saint anthony
# Processing Record 23 of Set 5 | birur
# Processing Record 24 of Set 5 | thompson
# Processing Record 25 of Set 5 | jackson
# Processing Record 26 of Set 5 | gopalpur
# Processing Record 27 of Set 5 | kavaratti
# Processing Record 28 of Set 5 | hohhot
# Processing Record 29 of Set 5 | kaeo
# Processing Record 30 of Set 5 | diamantino
# Processing Record 31 of Set 5 | clyde river
# Processing Record 32 of Set 5 | saint george
# Processing Record 33 of Set 5 | sakakah
# Processing Record 34 of Set 5 | rio gallegos
# Processing Record 35 of Set 5 | shimoda
# Processing Record 36 of Set 5 | formosa do rio preto
# Processing Record 37 of Set 5 | merauke
# Processing Record 38 of Set 5 | tulum
# Processing Record 39 of Set 5 | saint-pierre
# Processing Record 40 of Set 5 | baijiantan
# Processing Record 41 of Set 5 | khandyga
# Processing Record 42 of Set 5 | keningau
# Processing Record 43 of Set 5 | majene
# Processing Record 44 of Set 5 | jujuy
# City not found. Skipping...
# Processing Record 45 of Set 5 | deer park
# Processing Record 46 of Set 5 | port blair
# Processing Record 47 of Set 5 | antofagasta
# Processing Record 48 of Set 5 | trelew
# Processing Record 49 of Set 5 | southbridge
# Processing Record 50 of Set 5 | ilulissat
# Processing Record 1 of Set 6 | makakilo city
# Processing Record 2 of Set 6 | barrow
# Processing Record 3 of Set 6 | vaxjo
# Processing Record 4 of Set 6 | virginia beach
# Processing Record 5 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 6 of Set 6 | krivosheino
# Processing Record 7 of Set 6 | leshukonskoye
# Processing Record 8 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 9 of Set 6 | hare bay
# Processing Record 10 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 11 of Set 6 | fortuna
# Processing Record 12 of Set 6 | vestmanna
# Processing Record 13 of Set 6 | praia
# Processing Record 14 of Set 6 | sisimiut
# Processing Record 15 of Set 6 | otjimbingwe
# Processing Record 16 of Set 6 | ahuimanu
# Processing Record 17 of Set 6 | victoria
# Processing Record 18 of Set 6 | sabang
# Processing Record 19 of Set 6 | kamenka
# Processing Record 20 of Set 6 | sinnamary
# Processing Record 21 of Set 6 | hofn
# Processing Record 22 of Set 6 | tarata
# Processing Record 23 of Set 6 | miandrivazo
# Processing Record 24 of Set 6 | san quintin
# Processing Record 25 of Set 6 | waipawa
# Processing Record 26 of Set 6 | stargard szczecinski
# Processing Record 27 of Set 6 | kaitangata
# Processing Record 28 of Set 6 | soyo
# Processing Record 29 of Set 6 | addis zemen
# City not found. Skipping...
# Processing Record 30 of Set 6 | alice springs
# Processing Record 31 of Set 6 | lorengau
# Processing Record 32 of Set 6 | bontang
# Processing Record 33 of Set 6 | lat yao
# Processing Record 34 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 35 of Set 6 | bara
# Processing Record 36 of Set 6 | kholtoson
# Processing Record 37 of Set 6 | camalu
# Processing Record 38 of Set 6 | kutum
# Processing Record 39 of Set 6 | gudari
# Processing Record 40 of Set 6 | newnan
# Processing Record 41 of Set 6 | guilin
# Processing Record 42 of Set 6 | sokode
# Processing Record 43 of Set 6 | deneysville
# Processing Record 44 of Set 6 | camacha
# Processing Record 45 of Set 6 | ballina
# Processing Record 46 of Set 6 | airai
# Processing Record 47 of Set 6 | touros
# Processing Record 48 of Set 6 | auki
# Processing Record 49 of Set 6 | xining
# Processing Record 50 of Set 6 | rimbey
# Processing Record 1 of Set 7 | coihaique
# Processing Record 2 of Set 7 | kawalu
# Processing Record 3 of Set 7 | lesogorskiy
# Processing Record 4 of Set 7 | matara
# Processing Record 5 of Set 7 | nelson bay
# Processing Record 6 of Set 7 | nouadhibou
# Processing Record 7 of Set 7 | gat
# Processing Record 8 of Set 7 | banda aceh
# Processing Record 9 of Set 7 | la peca
# Processing Record 10 of Set 7 | manadhoo
# Processing Record 11 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 12 of Set 7 | dujuma
# City not found. Skipping...
# Processing Record 13 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 14 of Set 7 | katsuura
# Processing Record 15 of Set 7 | la palma
# Processing Record 16 of Set 7 | rutul
# Processing Record 17 of Set 7 | halifax
# Processing Record 18 of Set 7 | asau
# Processing Record 19 of Set 7 | mao
# Processing Record 20 of Set 7 | chino valley
# Processing Record 21 of Set 7 | redcliffe
# Processing Record 22 of Set 7 | quatre cocos
# Processing Record 23 of Set 7 | jiuquan
# Processing Record 24 of Set 7 | beterou
# Processing Record 25 of Set 7 | iquique
# Processing Record 26 of Set 7 | tivoli
# Processing Record 27 of Set 7 | chakia
# Processing Record 28 of Set 7 | sarh
# Processing Record 29 of Set 7 | ukiah
# Processing Record 30 of Set 7 | aksu
# Processing Record 31 of Set 7 | taunggyi
# Processing Record 32 of Set 7 | dalvik
# Processing Record 33 of Set 7 | houma
# Processing Record 34 of Set 7 | kruisfontein
# Processing Record 35 of Set 7 | vanimo
# Processing Record 36 of Set 7 | nyergesujfalu
# Processing Record 37 of Set 7 | namatanai
# Processing Record 38 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 39 of Set 7 | ostrovnoy
# Processing Record 40 of Set 7 | stromness
# Processing Record 41 of Set 7 | luanda
# Processing Record 42 of Set 7 | amurzet
# Processing Record 43 of Set 7 | hit
# Processing Record 44 of Set 7 | cockburn town
# Processing Record 45 of Set 7 | altukhovo
# Processing Record 46 of Set 7 | lagoa
# Processing Record 47 of Set 7 | oranjemund
# Processing Record 48 of Set 7 | xingyi
# Processing Record 49 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 7 | ust-kuyga
# Processing Record 1 of Set 8 | batagay
# Processing Record 2 of Set 8 | margate
# Processing Record 3 of Set 8 | port augusta
# Processing Record 4 of Set 8 | havre-saint-pierre
# Processing Record 5 of Set 8 | totton
# Processing Record 6 of Set 8 | meulaboh
# Processing Record 7 of Set 8 | tezu
# Processing Record 8 of Set 8 | tessalit
# Processing Record 9 of Set 8 | kegayli
# City not found. Skipping...
# Processing Record 10 of Set 8 | vostok
# Processing Record 11 of Set 8 | gazanjyk
# Processing Record 12 of Set 8 | suntar
# Processing Record 13 of Set 8 | tuatapere
# Processing Record 14 of Set 8 | lavrentiya
# Processing Record 15 of Set 8 | ahipara
# Processing Record 16 of Set 8 | peace river
# Processing Record 17 of Set 8 | bubaque
# Processing Record 18 of Set 8 | jiddah
# City not found. Skipping...
# Processing Record 19 of Set 8 | los llanos de aridane
# Processing Record 20 of Set 8 | poum
# Processing Record 21 of Set 8 | yumen
# Processing Record 22 of Set 8 | plainview
# Processing Record 23 of Set 8 | sodertalje
# City not found. Skipping...
# Processing Record 24 of Set 8 | mandalgovi
# Processing Record 25 of Set 8 | hervey bay
# Processing Record 26 of Set 8 | nosy varika
# Processing Record 27 of Set 8 | kununurra
# Processing Record 28 of Set 8 | grindavik
# Processing Record 29 of Set 8 | colares
# Processing Record 30 of Set 8 | soller
# Processing Record 31 of Set 8 | qaqortoq
# Processing Record 32 of Set 8 | tsiroanomandidy
# Processing Record 33 of Set 8 | macau
# Processing Record 34 of Set 8 | omboue
# Processing Record 35 of Set 8 | ribeira grande
# Processing Record 36 of Set 8 | boende
# Processing Record 37 of Set 8 | oliveira dos brejinhos
# Processing Record 38 of Set 8 | porbandar
# Processing Record 39 of Set 8 | aljezur
# Processing Record 40 of Set 8 | la ronge
# Processing Record 41 of Set 8 | izumo
# Processing Record 42 of Set 8 | dunmore east
# Processing Record 43 of Set 8 | victor harbor
# Processing Record 44 of Set 8 | saquena
# Processing Record 45 of Set 8 | kuznechnoye
# Processing Record 46 of Set 8 | maroua
# Processing Record 47 of Set 8 | macas
# Processing Record 48 of Set 8 | dingle
# Processing Record 49 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 50 of Set 8 | troitskoye
# Processing Record 1 of Set 9 | sibu
# Processing Record 2 of Set 9 | grandview
# Processing Record 3 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 4 of Set 9 | udala
# Processing Record 5 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 9 | marathon
# Processing Record 7 of Set 9 | morant bay
# Processing Record 8 of Set 9 | vila velha
# Processing Record 9 of Set 9 | vila franca do campo
# Processing Record 10 of Set 9 | huitzuco
# City not found. Skipping...
# Processing Record 11 of Set 9 | balagansk
# Processing Record 12 of Set 9 | bathsheba
# Processing Record 13 of Set 9 | havoysund
# Processing Record 14 of Set 9 | sheridan
# Processing Record 15 of Set 9 | saldanha
# Processing Record 16 of Set 9 | maryville
# Processing Record 17 of Set 9 | kanigoro
# Processing Record 18 of Set 9 | holme
# Processing Record 19 of Set 9 | copiapo
# Processing Record 20 of Set 9 | upernavik
# Processing Record 21 of Set 9 | acapulco
# Processing Record 22 of Set 9 | presidente olegario
# Processing Record 23 of Set 9 | sergeyevka
# Processing Record 24 of Set 9 | beringovskiy
# Processing Record 25 of Set 9 | georgetown
# Processing Record 26 of Set 9 | baruun-urt
# Processing Record 27 of Set 9 | motygino
# Processing Record 28 of Set 9 | tazovskiy
# Processing Record 29 of Set 9 | lata
# Processing Record 30 of Set 9 | guapiacu
# Processing Record 31 of Set 9 | mehamn
# Processing Record 32 of Set 9 | bethanien
# Processing Record 33 of Set 9 | maromitsa
# Processing Record 34 of Set 9 | kavieng
# Processing Record 35 of Set 9 | donskoye
# Processing Record 36 of Set 9 | keffi
# Processing Record 37 of Set 9 | malangas
# Processing Record 38 of Set 9 | tilichiki
# Processing Record 39 of Set 9 | xuanhua
# Processing Record 40 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 41 of Set 9 | brasileia
# Processing Record 42 of Set 9 | shenjiamen
# Processing Record 43 of Set 9 | pangai
# Processing Record 44 of Set 9 | nurota
# Processing Record 45 of Set 9 | gimli
# Processing Record 46 of Set 9 | san cristobal
# Processing Record 47 of Set 9 | kenai
# Processing Record 48 of Set 9 | ramona
# Processing Record 49 of Set 9 | kawana waters
# City not found. Skipping...
# Processing Record 50 of Set 9 | weiser
# Processing Record 1 of Set 10 | ambon
# Processing Record 2 of Set 10 | bilma
# Processing Record 3 of Set 10 | lodwar
# Processing Record 4 of Set 10 | la cruz
# Processing Record 5 of Set 10 | carauari
# Processing Record 6 of Set 10 | kollumerland
# City not found. Skipping...
# Processing Record 7 of Set 10 | jacareacanga
# Processing Record 8 of Set 10 | keflavik
# Processing Record 9 of Set 10 | ostersund
# Processing Record 10 of Set 10 | tura
# Processing Record 11 of Set 10 | san juan
# Processing Record 12 of Set 10 | pierre
# Processing Record 13 of Set 10 | nevsehir
# Processing Record 14 of Set 10 | talnakh
# Processing Record 15 of Set 10 | yakeshi
# Processing Record 16 of Set 10 | belogorsk
# Processing Record 17 of Set 10 | doha
# Processing Record 18 of Set 10 | mangai
# Processing Record 19 of Set 10 | san jose
# Processing Record 20 of Set 10 | tam ky
# Processing Record 21 of Set 10 | hualmay
# Processing Record 22 of Set 10 | darhan
# Processing Record 23 of Set 10 | zeya
# Processing Record 24 of Set 10 | dibaya
# City not found. Skipping...
# Processing Record 25 of Set 10 | bandarban
# Processing Record 26 of Set 10 | nanortalik
# Processing Record 27 of Set 10 | shirokiy
# Processing Record 28 of Set 10 | flinders
# Processing Record 29 of Set 10 | waingapu
# Processing Record 30 of Set 10 | college
# Processing Record 31 of Set 10 | san matias
# Processing Record 32 of Set 10 | islamkot
# Processing Record 33 of Set 10 | kahului
# Processing Record 34 of Set 10 | myaundzha
# Processing Record 35 of Set 10 | san felipe
# Processing Record 36 of Set 10 | la macarena
# Processing Record 37 of Set 10 | baniachang
# Processing Record 38 of Set 10 | diplo
# Processing Record 39 of Set 10 | ginir
# Processing Record 40 of Set 10 | mbamba
# Processing Record 41 of Set 10 | luderitz
# Processing Record 42 of Set 10 | oussouye
# Processing Record 43 of Set 10 | khatanga
# Processing Record 44 of Set 10 | corner brook
# Processing Record 45 of Set 10 | ashqelon
# Processing Record 46 of Set 10 | sawtell
# Processing Record 47 of Set 10 | alta floresta
# Processing Record 48 of Set 10 | pangnirtung
# Processing Record 49 of Set 10 | narsaq
# Processing Record 50 of Set 10 | rocha
# Processing Record 1 of Set 11 | la libertad
# Processing Record 2 of Set 11 | fukue
# Processing Record 3 of Set 11 | santa cruz
# Processing Record 4 of Set 11 | marzuq
# Processing Record 5 of Set 11 | shubarshi
# Processing Record 6 of Set 11 | eureka
# Processing Record 7 of Set 11 | alyangula
# Processing Record 8 of Set 11 | zhicheng
# Processing Record 9 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 10 of Set 11 | ajra
# Processing Record 11 of Set 11 | fredericksburg
# Processing Record 12 of Set 11 | san carlos
# Processing Record 13 of Set 11 | boyolangu
# Processing Record 14 of Set 11 | tawnat
# City not found. Skipping...
# Processing Record 15 of Set 11 | surt
# Processing Record 16 of Set 11 | port hawkesbury
# Processing Record 17 of Set 11 | jaffna
# Processing Record 18 of Set 11 | gorin
# Processing Record 19 of Set 11 | general cepeda
# Processing Record 20 of Set 11 | kathmandu
# Processing Record 21 of Set 11 | banjarmasin
# Processing Record 22 of Set 11 | owando
# Processing Record 23 of Set 11 | santa rosa
# Processing Record 24 of Set 11 | coos bay
# Processing Record 25 of Set 11 | broome
# Processing Record 26 of Set 11 | luau
# Processing Record 27 of Set 11 | kirkkonummi
# Processing Record 28 of Set 11 | athabasca
# Processing Record 29 of Set 11 | honningsvag
# Processing Record 30 of Set 11 | muana
# Processing Record 31 of Set 11 | springbok
# Processing Record 32 of Set 11 | kalmunai
# Processing Record 33 of Set 11 | capaci
# Processing Record 34 of Set 11 | piploda
# Processing Record 35 of Set 11 | svetlaya
# Processing Record 36 of Set 11 | cayenne
# Processing Record 37 of Set 11 | porto novo
# Processing Record 38 of Set 11 | mahon
# Processing Record 39 of Set 11 | estelle
# Processing Record 40 of Set 11 | wharton
# Processing Record 41 of Set 11 | lakatoro
# Processing Record 42 of Set 11 | zhezkazgan
# Processing Record 43 of Set 11 | konya
# Processing Record 44 of Set 11 | xuddur
# Processing Record 45 of Set 11 | high level
# Processing Record 46 of Set 11 | westport
# Processing Record 47 of Set 11 | faya
# Processing Record 48 of Set 11 | bethel
# Processing Record 49 of Set 11 | krasnogorskoye
# Processing Record 50 of Set 11 | maniitsoq
# Processing Record 1 of Set 12 | patan
# Processing Record 2 of Set 12 | nhamunda
# Processing Record 3 of Set 12 | tshikapa
# Processing Record 4 of Set 12 | brownfield
# Processing Record 5 of Set 12 | gambela
# Processing Record 6 of Set 12 | brae
# Processing Record 7 of Set 12 | hendijan
# City not found. Skipping...
# Processing Record 8 of Set 12 | vao
# Processing Record 9 of Set 12 | isangel
# Processing Record 10 of Set 12 | san jeronimo
# Processing Record 11 of Set 12 | labutta
# City not found. Skipping...
# Processing Record 12 of Set 12 | liverpool
# Processing Record 13 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 14 of Set 12 | fare
# Processing Record 15 of Set 12 | moree
# Processing Record 16 of Set 12 | sampit
# Processing Record 17 of Set 12 | laje
# Processing Record 18 of Set 12 | ocampo
# Processing Record 19 of Set 12 | fairbanks
# Processing Record 20 of Set 12 | nishihara
# Processing Record 21 of Set 12 | chuka
# Processing Record 22 of Set 12 | nyuksenitsa
# Processing Record 23 of Set 12 | lakes entrance
# Processing Record 24 of Set 12 | gingoog
# Processing Record 25 of Set 12 | ourem
# Processing Record 26 of Set 12 | rio grande
# Processing Record 27 of Set 12 | opuwo
# Processing Record 28 of Set 12 | kloulklubed
# Processing Record 29 of Set 12 | zemio
# Processing Record 30 of Set 12 | sale
# Processing Record 31 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 32 of Set 12 | neiafu
# Processing Record 33 of Set 12 | garmsar
# Processing Record 34 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 35 of Set 12 | nizhniy kuranakh
# Processing Record 36 of Set 12 | khormuj
# City not found. Skipping...
# Processing Record 37 of Set 12 | wencheng
# Processing Record 38 of Set 12 | san lawrenz
# Processing Record 39 of Set 12 | loandjili
# Processing Record 40 of Set 12 | lubango
# Processing Record 41 of Set 12 | diapaga
# Processing Record 42 of Set 12 | sayanogorsk
# Processing Record 43 of Set 12 | eregli
# Processing Record 44 of Set 12 | lasa
# Processing Record 45 of Set 12 | angoche
# Processing Record 46 of Set 12 | obluche
# City not found. Skipping...
# Processing Record 47 of Set 12 | sorland
# Processing Record 48 of Set 12 | lubyany
# Processing Record 49 of Set 12 | keetmanshoop
# Processing Record 50 of Set 12 | mopipi
# Processing Record 1 of Set 13 | geraldton
# Processing Record 2 of Set 13 | gubkinskiy
# Processing Record 3 of Set 13 | maumere
# Processing Record 4 of Set 13 | craig
# Processing Record 5 of Set 13 | jieshi
# Processing Record 6 of Set 13 | san pedro
# Processing Record 7 of Set 13 | sao joao da barra
# Processing Record 8 of Set 13 | tucurui
# Processing Record 9 of Set 13 | sabha
# Processing Record 10 of Set 13 | campoverde
# Processing Record 11 of Set 13 | palmares do sul
# Processing Record 12 of Set 13 | perelyub
# Processing Record 13 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 14 of Set 13 | port-gentil
# Processing Record 15 of Set 13 | hambantota
# Processing Record 16 of Set 13 | bull savanna
# Processing Record 17 of Set 13 | hamirpur
# Processing Record 18 of Set 13 | kondinskoye
# Processing Record 19 of Set 13 | palanga
# Processing Record 20 of Set 13 | puerto quijarro
# Processing Record 21 of Set 13 | phalaborwa
# Processing Record 22 of Set 13 | arawa
# Processing Record 23 of Set 13 | baherden
# Processing Record 24 of Set 13 | tayga
# Processing Record 25 of Set 13 | itarema
# Processing Record 26 of Set 13 | bilibino
# Processing Record 27 of Set 13 | bogo
# Processing Record 28 of Set 13 | ambulu
# Processing Record 29 of Set 13 | kundiawa
# Processing Record 30 of Set 13 | nikko
# Processing Record 31 of Set 13 | sorkjosen
# Processing Record 32 of Set 13 | baykit
# Processing Record 33 of Set 13 | anage
# Processing Record 34 of Set 13 | laurel
# Processing Record 35 of Set 13 | eldama ravine
# Processing Record 36 of Set 13 | tucuman
# Processing Record 37 of Set 13 | gushi
# Processing Record 38 of Set 13 | gazalkent
# Processing Record 39 of Set 13 | santo domingo
# Processing Record 40 of Set 13 | oranjestad
# Processing Record 41 of Set 13 | mandera
# Processing Record 42 of Set 13 | bereda
# Processing Record 43 of Set 13 | manono
# Processing Record 44 of Set 13 | byron bay
# Processing Record 45 of Set 13 | ambovombe
# Processing Record 46 of Set 13 | seoul
# Processing Record 47 of Set 13 | queimadas
# Processing Record 48 of Set 13 | rassvet
# Processing Record 49 of Set 13 | wielun
# Processing Record 50 of Set 13 | pelym
# Processing Record 1 of Set 14 | tando ghulam ali
# Processing Record 2 of Set 14 | winnemucca
# Processing Record 3 of Set 14 | colorado
# Processing Record 4 of Set 14 | paciran
# Processing Record 5 of Set 14 | yeppoon
# Processing Record 6 of Set 14 | suluq
# Processing Record 7 of Set 14 | aykhal
# Processing Record 8 of Set 14 | vardo
# Processing Record 9 of Set 14 | itoman
# Processing Record 10 of Set 14 | puerto colombia
# Processing Record 11 of Set 14 | tommot
# Processing Record 12 of Set 14 | bosaso
# Processing Record 13 of Set 14 | sobolevo
# Processing Record 14 of Set 14 | revelstoke
# Processing Record 15 of Set 14 | methoni
# Processing Record 16 of Set 14 | tricase
# Processing Record 17 of Set 14 | portland
# Processing Record 18 of Set 14 | yuncheng
# Processing Record 19 of Set 14 | bonavista
# Processing Record 20 of Set 14 | atherton
# Processing Record 21 of Set 14 | araouane
# Processing Record 22 of Set 14 | horta
# Processing Record 23 of Set 14 | egvekinot
# Processing Record 24 of Set 14 | inhambane
# Processing Record 25 of Set 14 | baghdad
# Processing Record 26 of Set 14 | leninskoye
# Processing Record 27 of Set 14 | zheleznogorsk
# Processing Record 28 of Set 14 | bedesa
# Processing Record 29 of Set 14 | srednekolymsk
# Processing Record 30 of Set 14 | yar-sale
# Processing Record 31 of Set 14 | labuhan
# Processing Record 32 of Set 14 | stykkisholmur
# Processing Record 33 of Set 14 | kimparana
# Processing Record 34 of Set 14 | progreso
# Processing Record 35 of Set 14 | artyk
# City not found. Skipping...
# Processing Record 36 of Set 14 | khani
# Processing Record 37 of Set 14 | shimanovsk
# Processing Record 38 of Set 14 | kontagora
# Processing Record 39 of Set 14 | eastbourne
# Processing Record 40 of Set 14 | nyurba
# Processing Record 41 of Set 14 | mareeba
# Processing Record 42 of Set 14 | sayyan
# Processing Record 43 of Set 14 | parrita
# Processing Record 44 of Set 14 | atar
# Processing Record 45 of Set 14 | preston
# Processing Record 46 of Set 14 | fereydun kenar
# Processing Record 47 of Set 14 | susanville
# Processing Record 48 of Set 14 | matagami
# Processing Record 49 of Set 14 | isla mujeres
# Processing Record 50 of Set 14 | blackwater
# Processing Record 1 of Set 15 | koungheul
# Processing Record 2 of Set 15 | ciudad bolivar
# Processing Record 3 of Set 15 | yavaros
# Processing Record 4 of Set 15 | turka
# Processing Record 5 of Set 15 | baghmara
# Processing Record 6 of Set 15 | regina
# Processing Record 7 of Set 15 | pangkalanbuun
# Processing Record 8 of Set 15 | porto san giorgio
# Processing Record 9 of Set 15 | nabire
# Processing Record 10 of Set 15 | guisa
# Processing Record 11 of Set 15 | santa vitoria do palmar
# Processing Record 12 of Set 15 | burnie
# Processing Record 13 of Set 15 | willowmore
# Processing Record 14 of Set 15 | polonnaruwa
# Processing Record 15 of Set 15 | gamba
# Processing Record 16 of Set 15 | khash
# Processing Record 17 of Set 15 | itaituba
# Processing Record 18 of Set 15 | pakxan
# Processing Record 19 of Set 15 | canoinhas
# Processing Record 20 of Set 15 | chacaltianguis
# Processing Record 21 of Set 15 | sao jose da coroa grande
# Processing Record 22 of Set 15 | elko
# Processing Record 23 of Set 15 | churu
# Processing Record 24 of Set 15 | kharan
# Processing Record 25 of Set 15 | oyem
# Processing Record 26 of Set 15 | sioux lookout
# Processing Record 27 of Set 15 | maragogi
# Processing Record 28 of Set 15 | adrar
# Processing Record 29 of Set 15 | bayonet point
# Processing Record 30 of Set 15 | shasta lake
# Processing Record 31 of Set 15 | kargasok
# Processing Record 32 of Set 15 | kiruna
# Processing Record 33 of Set 15 | hobyo
# Processing Record 34 of Set 15 | batticaloa
# Processing Record 35 of Set 15 | freeport
# Processing Record 36 of Set 15 | obo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng Current Description  Max Temp  Humidity  \
# 0           Kapaa  22.0752 -159.3190          light rain     84.52        73
# 1       Hithadhoo  -0.6000   73.0833          light rain     83.41        73
# 2           Togur  58.3631   82.8265     overcast clouds     52.34        91
# 3     Mitsamiouli -11.3847   43.2844       broken clouds     75.60        79
# 4  Puerto Cabezas  14.0351  -83.3888       broken clouds     79.34        87
# 5         Hatillo  18.4863  -66.8254           clear sky     81.82        91
# 6            Hilo  19.7297 -155.0900          light rain     82.13        76
# 7         Rikitea -23.1203 -134.9692           clear sky     74.25        70
# 8    Longyearbyen  78.2186   15.6401       broken clouds     40.84        81
# 9         Ushuaia -54.8000  -68.3000       broken clouds     35.26        69
#
#    Cloudiness  Wind Speed Country
# 0           1        3.00      US
# 1         100        9.19      MV
# 2         100       11.34      RU
# 3          74       10.04      KM
# 4          65        7.52      NI
# 5           3       11.41      PR
# 6          40       11.50      US
# 7           0       13.24      PF
# 8          75        3.44      SJ
# 9          75       11.50      AR

# %%
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0             Kapaa      US  22.0752 -159.3190     84.52        73
# 1         Hithadhoo      MV  -0.6000   73.0833     83.41        73
# 2             Togur      RU  58.3631   82.8265     52.34        91
# 3       Mitsamiouli      KM -11.3847   43.2844     75.60        79
# 4    Puerto Cabezas      NI  14.0351  -83.3888     79.34        87
# ..              ...     ...      ...       ...       ...       ...
# 674          Kiruna      SE  67.8557   20.2251     38.32        87
# 675           Hobyo      SO   5.3505   48.5268     77.18        88
# 676      Batticaloa      LK   7.7102   81.6924     81.81        78
# 677        Freeport      US  40.6576  -73.5832     73.98        87
# 678             Obo      CF   5.3998   26.4869     66.43        99
#
#      Cloudiness  Wind Speed Current Description
# 0             1        3.00          light rain
# 1           100        9.19          light rain
# 2           100       11.34     overcast clouds
# 3            74       10.04       broken clouds
# 4            65        7.52       broken clouds
# ..          ...         ...                 ...
# 674          90        9.22     overcast clouds
# 675          42       21.36    scattered clouds
# 676          99        5.50     overcast clouds
# 677          90        5.99     overcast clouds
# 678         100        4.65     overcast clouds
#
# [679 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
